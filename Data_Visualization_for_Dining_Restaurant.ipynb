# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrhmannassef/Data-Visualization-for-Dining-Restaurant/blob/main/Data_Visualization_for_Dining_Restaurant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/content/drive/MyDrive/DATA/satisfaction.csv")
df.head()
# Out:
#        id satisfaction_v2  Gender   Customer Type  Age Type of Dining  \
# 0   11112       satisfied  Female  Loyal Customer   65       Personal
# 1  110278       satisfied    Male  Loyal Customer   47       Personal
# 2  103199       satisfied  Female  Loyal Customer   15       Personal
# 3   47462       satisfied  Female  Loyal Customer   60       Personal
# 4  120011       satisfied  Female  Loyal Customer   70       Personal
#
#    Ambiance  Distance from Home  Table Comfort  Reservation Convenience  ...  \
# 0       Eco                 265              0                        0  ...
# 1  Business                2464              0                        0  ...
# 2       Eco                2138              0                        0  ...
# 3       Eco                 623              0                        0  ...
# 4       Eco                 354              0                        0  ...
#
#    Entertainment Options  Online support  Ease of Online booking  \
# ...

# %%
df.drop(columns=['id'] , inplace = True)
df.head()
# Out:
#   satisfaction_v2  Gender   Customer Type  Age Type of Dining  Ambiance  \
# 0       satisfied  Female  Loyal Customer   65       Personal       Eco
# 1       satisfied    Male  Loyal Customer   47       Personal  Business
# 2       satisfied  Female  Loyal Customer   15       Personal       Eco
# 3       satisfied  Female  Loyal Customer   60       Personal       Eco
# 4       satisfied  Female  Loyal Customer   70       Personal       Eco
#
#    Distance from Home  Table Comfort  Reservation Convenience  \
# 0                 265              0                        0
# 1                2464              0                        0
# 2                2138              0                        0
# 3                 623              0                        0
# 4                 354              0                        0
#
#    Food and Drink Quality  ...  Entertainment Options  Online support  \
# 0                       0  ...                      4               2
# ...

# %%
target = "satisfaction_v2"
y = df[target]
X = df.drop(columns=[target])

# %%
X = pd.get_dummies(X)

# %%
x_train , x_test , y_train , y_test = train_test_split(X, y ,test_size = 0.3 , random_state = 42 )

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (90916, 26)
# (90916,)

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.79096088697259

# %%
classifier = RandomForestClassifier()
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred2)

# %%
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 95.84%

# %%
x_test.iloc[0,:]
# Out:
# Age                                  59
# Distance from Home                 1470
# Table Comfort                         4
# Reservation Convenience               4
# Food and Drink Quality                4
# Seating Location                      4
# WiFi Service                          5
# Entertainment Options                 4
# Online support                        4
# Ease of Online booking                4
# Table Service                         4
# Space Between Tables                  4
# Baggage handling                      4
# Checkin service                       5
# Cleanliness                           4
# Online Menu Access                    3
# Wait Time for a Table                 7
# Gender_Female                         1
# Gender_Male                           0
# Customer Type_Loyal Customer          1
# Customer Type_disloyal Customer       0
# Type of Dining_Business               1
# Type of Dining_Personal               0
# ...

# %%
y_test[0]
# Out:
# 'satisfied'

# %%
predction = classifier.predict(x_test.iloc[0,:].to_numpy().reshape(1,-1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(predction)
# Out:
# ['satisfied']
